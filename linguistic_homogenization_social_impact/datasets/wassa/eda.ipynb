# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("clean_wassa.csv")

# %%
texts = df["text"]
text_lengths = [len(text.split()) for text in texts]
plt.hist(text_lengths, bins=100)
plt.show()
