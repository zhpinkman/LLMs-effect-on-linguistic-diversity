# %%
import json
import pandas as pd
import numpy as np
import os

# %%
main_columns = [
    "Care",
    "Fairness",
    "Loyalty",
    "Authority",
    "Purity",
    "age",
    "gender",
    "z.care",
    "z.fairness",
    "z.loyalty",
    "z.authority",
    "z.purity",
    "c.care",
    "c.fairness",
    "c.loyalty",
    "c.authority",
    "c.purity",
    "subject_id",
    "text",
]

# %%
for file in [
    "full_dataset_clean.csv",
    "facebook_rewritten_rephrase_gemini_cleaned.csv",
    "facebook_rewritten_rephrase_gpt_cleaned.csv",
    "facebook_rewritten_rephrase_llama_cleaned.csv",
    "facebook_rewritten_syntax_grammar_gemini_cleaned.csv",
    "facebook_rewritten_syntax_grammar_gpt_cleaned.csv",
    "facebook_rewritten_syntax_grammar_llama_cleaned.csv",
]:
    df = pd.read_csv(file)
    df = df[main_columns]
    df.to_csv(file, index=False)

# %%
import pandas as pd

# %%
df = pd.read_csv("full_dataset_clean.csv")

# %%
df.Loyalty.hist()
# Out:
# <Axes: >

# %%
df["z.loyalty"].hist()
# Out:
# <Axes: >
